# %%
import pandas as pd
import numpy as np

import seaborn as sns   
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
cd ~/.kaggle/
# Out:
# C:\Users\muham\.kaggle

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 90A4-942A
#
#  Directory of C:\Users\muham\.kaggle
#
# 25.12.2021  22:19    <DIR>          .
# 25.12.2021  22:19    <DIR>          ..
#                0 File(s)              0 bytes
#                2 Dir(s)   1.183.875.072 bytes free

# %%
mkdir carprice
# Out:
# A subdirectory or file carprice already exists.

# %%
cd carprice
# Out:
# C:\users\muham\PYTHON_ALISTIRMALARIM\bookcamp\chapter-02-car-price\cardataset\cardataset\carprice

# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !kaggle datasets list -s 'cardataset'
# Out:
# ref                                title                   size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------  ---------------------  -----  -------------------  -------------  ---------  ---------------
# mohamedalkhiami/cardataset         CarDataSet              35MB  2021-01-28 07:41:39              5          0  0.375
# iamsandeepprasad/vehicle-data-set  Vehicle Data Set         5GB  2020-06-16 09:19:14            424         22  0.5625
# susiezh/cardataset                 cardataset               7MB  2020-08-23 09:57:20             10          0  0.1875
# CooperUnion/cardataset             Car Features and MSRP  103KB  2016-12-21 19:27:34          28522        478  0.7647059
# maragatha/cardataset               cardataset             221KB  2019-11-29 07:40:32              8          0  0.11764706
# serkanme/cardataset                cardataset             103KB  2020-04-19 06:51:10              2          0  0.11764706
# ...

# %%
cd ..
# Out:
# C:\

# %%
cd/users/muham
# Out:
# C:\users\muham

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 90A4-942A
#
#  Directory of C:\users\muham
#
# 25.12.2021  22:19    <DIR>          .
# 25.12.2021  22:19    <DIR>          ..
# 25.12.2021  22:28    <DIR>          .conda
# 25.12.2021  22:02                84 .condarc
# 13.08.2021  14:32    <DIR>          .dotnet
# 05.08.2021  02:13               214 .gitconfig
# 20.11.2021  14:36    <DIR>          .ipynb_checkpoints
# 08.04.2021  18:16    <DIR>          .ipython
# 14.07.2021  21:05    <DIR>          .jupyter
# 25.12.2021  22:23    <DIR>          .kaggle
# 05.08.2021  01:31    <DIR>          .keras
# 15.07.2021  23:49    <DIR>          .matplotlib
# 16.10.2021  23:12    <DIR>          .spss
# 30.01.2021  08:34    <DIR>          3D Objects
# 18.07.2021  03:58    <DIR>          anaconda3
# 30.01.2021  08:34    <DIR>          Contacts
# 25.12.2021  20:41    <DIR>          Desktop
# 20.11.2021  20:19    <DIR>          Documents
# 25.12.2021  22:23    <DIR>          Downloads
# ...

# %%
cd PYTHON_ALISTIRMALARIM
# Out:
# C:\users\muham\PYTHON_ALISTIRMALARIM

# %%
cd carprice
# Out:
# C:\users\muham\PYTHON_ALISTIRMALARIM\bookcamp

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 90A4-942A
#
#  Directory of C:\users\muham\PYTHON_ALISTIRMALARIM\bookcamp
#
# 25.12.2021  22:29    <DIR>          .
# 25.12.2021  22:29    <DIR>          ..
# 25.12.2021  22:05    <DIR>          .ipynb_checkpoints
# 25.12.2021  22:12    <DIR>          chapter-02-car-price
# 25.12.2021  22:29            13.695 Untitled.ipynb
#                1 File(s)         13.695 bytes
#                4 Dir(s)   1.181.941.760 bytes free

# %%
cd carprice
# Out:
# C:\users\muham\PYTHON_ALISTIRMALARIM\bookcamp\chapter-02-car-price

# %%
# !kaggle datasets download -d CooperUnion/cardataset
# Out:
# ...
#   0%|          | 0.00/103k [00:00<?, ?B/s]
# 100%|##########| 103k/103k [00:05<00:00, 20.3kB/s]
# 100%|##########| 103k/103k [00:05<00:00, 20.3kB/s]

# %%
import zipfile
with zipfile.ZipFile("cardataset.zip","r") as zip_ref:
    zip_ref.extractall("cardataset")

# %%
df = pd.read_csv('data.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
len(df)
# Out:
# 11914

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_') 
 
string_columns = list(df.dtypes[df.dtypes == 'object'].index) 
 
for col in string_columns: 
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
#target analiz

# %%
sns.distplot(df.msrp, kde = False)
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='msrp'>

# %%
#dağılım incelendiğinde düşük fiyata sahip çok fazla araba olduğu ve grafiğin sağa çarpık olduğu ve sağ tarafta yüksek fiyatlıların uzatması göze çarpmakta.

# %%
#yüz bin aşağısına dikkatli bakalım.

# %%
sns.distplot(df.msrp[df.msrp < 100000], kde=False)
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='msrp'>

# %%
#dağılım dahaiyi ama modelin kafasını karıstırabilir bir log dönüşümü ile inceleyelim

# %%
log_price = np.log1p(df.msrp)

# %%
sns.distplot(log_price, kde=False)
# Out:
# <AxesSubplot:xlabel='msrp'>

# %%
#dönüşümün uzun kuyyrugu sildigini görüyoruz. model hala normal değil ama 0 tarafında bir yığıntı olmasını da modeller anlayacaktır. O yüzden böyle devam edilebilir.

# %%
df.isnull().sum() #missing
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
n = len(df) # row sayısı
 
n_val = int(0.2 * n) # kaç tane val gidecek
n_test = int(0.2 * n) # kac tane test gidecek
n_train = n - (n_val + n_test) # kac tane training gidecek
 
np.random.seed(2) # seed işleömi
idx = np.arange(n) # from 0 to n-1
np.random.shuffle(idx) # shuffle
 
df_shuffled = df.iloc[idx] # shuffled veri
 
df_train = df_shuffled.iloc[:n_train].copy() # karistirilmis veriyi train val test alma
df_val = df_shuffled.iloc[n_train:n_train+n_val].copy() 
df_test = df_shuffled.iloc[n_train+n_val:].copy()

# %%
df_shuffled.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
#target'a log+1
y_train = np.log1p(df_train.msrp.values) 
y_val = np.log1p(df_val.msrp.values) 
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([ 9.57574708,  9.887663  ,  9.89323518, ..., 10.45380308,
#        12.62248099, 10.54061978])

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 
        'popularity'] 
df_num = df_train[base]

# %%
df_num = df_num.fillna(0) #missing ler 0

# %%
X_train = df_num.values

# %%
w_0, w = linear_regression(X_train, y_train)

# %%
y_pred = w_0 + X_train.dot(w)

# %%
sns.distplot(y_pred,  label='prediction') 
sns.distplot(y_train, label='target') 
plt.legend()                         #tahmin ve train
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def rmse(y, y_pred): 
    error = y_pred - y # hata fark
    mse = (error ** 2).mean() # hata karaler ort
    return np.sqrt(mse) # hata karaler ort karekök

# %%
rmse(y_train,y_pred)   #diğer modellerle karşılastırmak üzere 0.76 kullanabilir bu sayı ortalama oldugunu söyler genelde 0.7 aşağısıysa az denilebilir 0 dan 1 gittikçe kötüleşir  test için rmse daha fazlaysa traine göre overfit yaklaşır denilebilir.
# Out:
# 0.7554192603920132

# %%
df_num = df_val[base]

# %%
 df_num = df_num.fillna(0) 
X_val = df_num.values

# %%
y_pred = w_0 + X_val.dot(w)

# %%
 rmse(y_val, y_pred)    #vale göre overgfit yok
# Out:
# 0.7616530991301591

# %%
#feature eng

# %%
df_train.year.max()
# Out:
# 2017

# %%
df_train['age'] = 2017 - df_train.year

# %%
def prepare_X(df): 
    df = df.copy() # kopya
    features = base.copy() # değişkenler copy
 
    df['age'] = 2017 - df.year # age computing 
    features.append('age') # age ekleme model içerisinde kullanmak için
 
    df_num = df[features] 
    df_num = df_num.fillna(0) 
    X = df_num.values 
    return X

# %%
X_train = prepare_X(df_train) 
w_0, w = linear_regression(X_train, y_train) 
 
X_val = prepare_X(df_val) 
y_pred = w_0 + X_val.dot(w) 
print('validation:', rmse(y_val, y_pred))
# Out:
# validation: 0.5172055461058328

# %%
#val hatası düştü tahminler ve val i gözlemleyelim

# %%
sns.distplot(y_pred, label='prediction') 
sns.distplot(y_val, label='target') 
plt.legend()
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#daha iyi oldu.

# %%
df.number_of_doors
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 11909    4.0
# 11910    4.0
# 11911    4.0
# 11912    4.0
# 11913    4.0
# Name: number_of_doors, Length: 11914, dtype: float64

# %%
#binary yapılabilir

# %%
v and feature
# Out:
# 'num_doors_2'

# %%
features = []
for v in [2, 3, 4]:   
    feature = 'num_doors_%s' % v 
    value = (df['number_of_doors'] == v).astype(int) 
    df[feature] = value 
    features.append(feature)

# %%
 df['make'].value_counts().head(5)
# Out:
# chevrolet     1123
# ford           881
# volkswagen     809
# toyota         746
# dodge          626
# Name: make, dtype: int64

# %%
for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']: 
    feature = 'is_make_%s' % v 
    df[feature] = (df['make'] == v).astype(int) 
    features.append(feature)

# %%
features
# Out:
# ['num_doors_2',
#  'num_doors_3',
#  'num_doors_4',
#  'is_make_chevrolet',
#  'is_make_ford',
#  'is_make_volkswagen',
#  'is_make_toyota',
#  'is_make_dodge']

# %%
def prepare_X(df): 
    df = df.copy() 
    features = base.copy() 
 
    df['age'] = 2017 - df.year 
    features.append('age') 
 
    for v in [2, 3, 4]: #kapı sayıları
        feature = 'num_doors_%s' % v 
        df[feature] = (df['number_of_doors'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']: #bunun içinde binary
        feature = 'is_make_%s' % v 
        df[feature] = (df['make'] == v).astype(int) 
        features.append(feature) 
 
    df_num = df[features] 
    df_num = df_num.fillna(0) 
    X = df_num.values 
    return X

# %%
X_train = prepare_X(df_train) 
w_0, w = linear_regression(X_train, y_train) 
 
X_val = prepare_X(df_val) 
y_pred = w_0 + X_val.dot(w) 
print('validation:', rmse(y_val, y_pred))
# Out:
# validation: 0.5076038849557535

# %%
#bütün hepsi için bakalim

# %%
def prepare_X(df): 
    df = df.copy() 
    features = base.copy() 
    df['age'] = 2017 - df.year 
    features.append('age') 
     
    for v in [2, 3, 4]: 
        feature = 'num_doors_%s' % v 
        df[feature] = (df['number_of_doors'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']: 
        feature = 'is_make_%s' % v 
        df[feature] = (df['make'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['regular_unleaded', 'premium_unleaded_(required)',  
              'premium_unleaded_(recommended)',  
              'flex-fuel_(unleaded/e85)']:
        feature = 'is_type_%s' % v 
        df[feature] = (df['engine_fuel_type'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['automatic', 'manual', 'automated_manual']:
        feature = 'is_transmission_%s' % v 
        df[feature] = (df['transmission_type'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['front_wheel_drive', 'rear_wheel_drive', 
              'all_wheel_drive', 'four_wheel_drive']: 
        feature = 'is_driven_wheels_%s' % v 
        df[feature] = (df['driven_wheels'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['crossover', 'flex_fuel', 'luxury',  
              'luxury,performance', 'hatchback']:  
        feature = 'is_mc_%s' % v 
        df[feature] = (df['market_category'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['compact', 'midsize', 'large']: 
        feature = 'is_size_%s' % v 
        df[feature] = (df['vehicle_size'] == v).astype(int) 
        features.append(feature) 
 
    for v in ['sedan', '4dr_suv', 'coupe', 'convertible', 
              '4dr_hatchback']:
        feature = 'is_style_%s' % v 
        df[feature] = (df['vehicle_style'] == v).astype(int) 
        features.append(feature) 
 
    df_num = df[features] 
    df_num = df_num.fillna(0) 
    X = df_num.values 
    return X

# %%
#val e göre test edelim
X_train = prepare_X(df_train) 
w_0, w = linear_regression(X_train, y_train) 
 
X_val = prepare_X(df_val) 
y_pred = w_0 + X_val.dot(w) 
print('validation:', rmse(y_val, y_pred))
# Out:
# validation: 174.1638915549478

# %%
#kötü sonuç çıktı her zaman yeni feature eklemek işe yaramaz.

# %%
def linear_regression_reg(X, y, r=0.0): 
    ones = np.ones(X.shape[0]) 
    X = np.column_stack([ones, X]) 
 
    XTX = X.T.dot(X) 
    reg = r * np.eye(XTX.shape[0]) 
    XTX = XTX + reg 
 
    XTX_inv = np.linalg.inv(XTX) 
    w = XTX_inv.dot(X.T).dot(y) 
 
    return w[0], w[1:]

# %%
for r in [0, 0.001, 0.01, 0.1, 1, 10]: 
    w_0, w = linear_regression_reg(X_train, y_train, r=r) 
    print('%5s, %.2f, %.2f, %.2f' % (r, w_0, w[13], w[21]))
# Out:
#     0, -19818095814540980.00, 14.38, 19818095814526776.00
# 0.001, 7.20, -0.10, 1.81
#  0.01, 7.18, -0.10, 1.81
#   0.1, 7.05, -0.10, 1.78
#     1, 6.22, -0.10, 1.56
#    10, 4.39, -0.09, 1.08

# %%
X_train = prepare_X(df_train) 
w_0, w = linear_regression_reg(X_train, y_train, r=0.001) 
 
X_val = prepare_X(df_val) 
y_pred = w_0 + X_val.dot(w) 
print('validation:', rmse(y_val, y_pred))
# Out:
# validation: 0.4602267628772416

# %%
#val şuan 0.001 için 0ç507 den daha iyi geldi

# %%
# en iyi r parametresi için searching
X_train = prepare_X(df_train) 
X_val = prepare_X(df_val) 
 
for r in [0.000001, 0.0001, 0.001, 0.01, 0.1, 1, 5, 10]: 
    w_0, w = linear_regression_reg(X_train, y_train, r=r) 
    y_pred = w_0 + X_val.dot(w) 
    print('%6s' %r, rmse(y_val, y_pred))
# Out:
#  1e-06 0.4602247826002159
# 0.0001 0.46022549106791727
#  0.001 0.4602267628772416
#   0.01 0.4602394963362205
#    0.1 0.4603700695763028
#      1 0.46182980426522546
#      5 0.4684079627530909
#     10 0.4757248100695974

# %%
#final modeli 0.01 iöin yapmaya karar verdim. test ile hatayı tahmin edelim

# %%
X_train = prepare_X(df_train) 
w_0, w = linear_regression_reg(X_train, y_train, r=0.01) 
 
X_val = prepare_X(df_val) 
y_pred = w_0 + X_val.dot(w) 
print('validation:', rmse(y_val, y_pred)) 
 
X_test = prepare_X(df_test) 
y_pred = w_0 + X_test.dot(w) 
print('test:', rmse(y_test, y_pred))
# Out:
# validation: 0.4602394963362205
# test: 0.4571813679504004

# %%
#yeni veri sokup deneyelim predictiona bakalım istediğimiz değerlerle ile araba fiyatını tahmin edelim

# %%
ad = { 
    'city_mpg': 18, 
    'driven_wheels': 'all_wheel_drive', 
    'engine_cylinders': 6.0, 
    'engine_fuel_type': 'regular_unleaded', 
    'engine_hp': 268.0, 
    'highway_mpg': 25, 
    'make': 'toyota', 
    'market_category': 'crossover,performance', 
    'model': 'venza', 
    'number_of_doors': 4.0, 
    'popularity': 2031, 
    'transmission_type': 'automatic', 
    'vehicle_size': 'midsize', 
    'vehicle_style': 'wagon', 
    'year': 2013 
}

# %%
df_test = pd.DataFrame([ad]) 
X_test = prepare_X(df_test)

# %%
y_pred = w_0 + X_test.dot(w)

# %%
suggestion = np.expm1(y_pred) 
suggestion
# Out:
# array([28294.13594119])

# %%
#sonuc arabanın reel fiyatına çok yakın modelimiz işlevli
